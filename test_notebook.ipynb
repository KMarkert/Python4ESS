# %% [markdown]
# # Test Header 1
# ## Test Header 2
# ### Test Header 3
# #### Test Header 4
#
# Initializing the IPython enviroment

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
x = arange(0,361)

# %% [markdown]
# #### Sine equation
# $sin\,\alpha = {\dfrac{opposite}{hypotenuse}}$

# %%
y = sin(x)
plot(y)

# %% [markdown]
# Something is wrong with the output...the frquecy is too high for 360$^\circ$. This is due to Python doing mathematical equations in radians. Now we have to convert the 0-360$^\circ$ to radians and then do the calculations.

# %%
rads = deg2rad(x)
y = sin(rads)
plot(y)

# %% [markdown]
# ##### This looks much better!
